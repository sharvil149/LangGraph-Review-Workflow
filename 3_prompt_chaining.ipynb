# %%
from langgraph.graph import StateGraph,START,END
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(
    model = "llama-3.1-8b-instant",
    temperature =0.2
)

# %%
class BlogState(TypedDict):
    title: str
    outline : str
    content : str

# %%
def create_outline(state:BlogState)-> BlogState:

    title = state['title']

    prompt = f'Generate an outline for a blog on the topic - {title}'

    outline = model.invoke(prompt).content

    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState)->BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title-{title} using the following outline-{outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initial_state = {'title':'Rise of Ai in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of Ai in India', 'outline': '**Title:** "The Rise of AI in India: Opportunities, Challenges, and Future Prospects"\n\n**I. Introduction**\n\n* Brief overview of AI and its growing importance globally\n* Importance of India in the AI landscape\n* Thesis statement: India is poised to become a major player in the AI ecosystem, driven by government initiatives, technological advancements, and entrepreneurial spirit.\n\n**II. Government Initiatives and Policies**\n\n* Overview of government initiatives such as:\n + Digital India\n + Make in India\n + Start-up India\n + AI for All\n* Analysis of policies and regulations supporting AI development and adoption\n* Impact of government initiatives on the growth of AI in India\n\n**III. Technological Advancements and Infrastructure**\n\n* Overview of AI-related technological advancements in India:\n + Machine learning and deep learning\n + Natural language processing\n + Computer vision\n + Robotics\n* Discussion of infrastructure development, including:\n + Data centers and cloud computing\n + High-performance computing\n + AI-specific hardware and software\n\n**IV. Entrepreneurial Spirit and Start-ups**\n\n* Overview of AI-related start-ups in India:\n + Success stories and notable companies\n + Challenges faced by start-ups in the AI space\n* Discussion of incubators, accelerators, and funding opportunities for AI start-ups\n\n**V. Applications and Use Cases**\n\n* Overview of AI applications in various sectors:\n + Healthcare\n + Finance\n + Education\n + Transportation\n + Agriculture\n* Analysis of success stories and case studies\n\n**VI. Challenges and Concerns**\n\n* Discussion of challenges and concerns related to AI in India:\n + Data privacy and security\n + Job displacement and skills gap\n + Bias and ethics in AI\n + Regulatory frameworks and governance\n\n**VII. Future Prospects and Opportunities**\n\n* Analysis of future prospects and opportunities for AI in India:\n + Emerging trends and technologies\n + Potential applications and use cases\n + Role of AI in achieving India\'s development goals\n\n**VIII. Conclusion**\n\n* Recap of key points and takeaways\n* Final thoughts on the rise of AI in India and its potential to transform the country.\n\n**IX. References**\n\n* List of sources used in the blog post.', 'content': "**The Rise of AI in India: Opportunities, Challenges, and Future Prospects**\n\nArtificial Intelligence (AI) has become a transformative force globally, revolutionizing industries and transforming the way we live and work. As the world becomes increasingly dependent on AI, India is poised to become a major player in the AI ecosystem. With its growing economy, entrepreneurial spirit, and government initiatives, India is well-positioned to harness the power of AI and drive innovation.\n\n**I. Introduction**\n\nAI has become a crucial component of modern technology, with applications in various sectors such as healthcare, finance, education, and transportation. The global AI market is expected to reach $190 billion by 2025, with India playing a significant role in its growth. The Indian government has recognized the potential of AI and has launched several initiatives to promote its development and adoption.\n\n**II. Government Initiatives and Policies**\n\nThe Indian government has launched several initiatives to promote AI development and adoption:\n\n1. **Digital India**: Launched in 2015, Digital India aims to transform India into a digitally empowered society and knowledge economy. The initiative has led to the development of digital infrastructure, including high-speed internet connectivity and data centers.\n2. **Make in India**: Launched in 2014, Make in India aims to promote manufacturing in India and make the country a global hub for manufacturing. The initiative has led to the development of AI-related manufacturing capabilities, including robotics and automation.\n3. **Start-up India**: Launched in 2016, Start-up India aims to p ...

# %%
print(final_state['outline'])
# Out:
# **Title:** "The Rise of AI in India: Opportunities, Challenges, and Future Prospects"
#
# **I. Introduction**
#
# * Brief overview of AI and its growing importance globally
# * Importance of India in the AI landscape
# * Thesis statement: India is poised to become a major player in the AI ecosystem, driven by government initiatives, technological advancements, and entrepreneurial spirit.
#
# **II. Government Initiatives and Policies**
#
# * Overview of government initiatives such as:
#  + Digital India
#  + Make in India
#  + Start-up India
#  + AI for All
# * Analysis of policies and regulations supporting AI development and adoption
# * Impact of government initiatives on the growth of AI in India
#
# **III. Technological Advancements and Infrastructure**
#
# * Overview of AI-related technological advancements in India:
#  + Machine learning and deep learning
#  + Natural language processing
#  + Computer vision
#  + Robotics
# * Discussion of infrastructure development, including:
#  + Data centers and cloud computing
#  + High-performance computing
#  + AI-specific hardware and software
#
# **IV. Entrepreneurial Spirit and Start-ups**
#
# * Overview of AI-related start-ups in India:
#  + Success stories and notable companies
#  + Challenges faced by start-ups in the AI space
# * Discussion of incubators, accelerators, and funding opportunities for AI start-ups
#
# **V. Applications and Use Cases**
#
# * Overview of AI applications in various sectors:
#  + Healthcare
#  + Finance
#  + Education
#  + Transportation
#  + Agriculture
# * Analysis of success stories and case studies
#
# **VI. Challenges and Concerns**
#
# * Discussion of challenges and concerns related to AI in India:
#  + Data privacy and security
#  + Job displacement and skills gap
#  + Bias and ethics in AI
#  + Regulatory frameworks and governance
#
# **VII. Future Prospects and Opportunities**
#
# * Analysis of future prospects and opportunities for AI in India:
#  + Emerging trends and technologies
#  + Potential applications and use cases
#  + Role of AI in achieving India's development goals
#
# **VIII. Conclusion**
#
# * Recap of key points and takeaways
# * Final thoughts on the rise of AI in India and its potential to transform the country.
#
# **IX. References**
#
# * List of sources used in the blog post.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Opportunities, Challenges, and Future Prospects**
#
# Artificial Intelligence (AI) has become a transformative force globally, revolutionizing industries and transforming the way we live and work. As the world becomes increasingly dependent on AI, India is poised to become a major player in the AI ecosystem. With its growing economy, entrepreneurial spirit, and government initiatives, India is well-positioned to harness the power of AI and drive innovation.
#
# **I. Introduction**
#
# AI has become a crucial component of modern technology, with applications in various sectors such as healthcare, finance, education, and transportation. The global AI market is expected to reach $190 billion by 2025, with India playing a significant role in its growth. The Indian government has recognized the potential of AI and has launched several initiatives to promote its development and adoption.
#
# **II. Government Initiatives and Policies**
#
# The Indian government has launched several initiatives to promote AI development and adoption:
#
# 1. **Digital India**: Launched in 2015, Digital India aims to transform India into a digitally empowered society and knowledge economy. The initiative has led to the development of digital infrastructure, including high-speed internet connectivity and data centers.
# 2. **Make in India**: Launched in 2014, Make in India aims to promote manufacturing in India and make the country a global hub for manufacturing. The initiative has led to the development of AI-related manufacturing capabilities, including robotics and automation.
# 3. **Start-up India**: Launched in 2016, Start-up India aims to promote entrepreneurship and start-ups in India. The initiative has led to the growth of AI-related start-ups, including companies like Haptik and Zoho.
# 4. **AI for All**: Launched in 2018, AI for All aims to promote AI development and adoption in India. The initiative has led to the development of AI-related education and training programs, including courses on machine learning and deep learning.
#
# The government has also introduced policies and regulations to support AI development and adoption, including:
#
# * **National Policy on AI**: Launched in 2018, the National Policy on AI aims to promote AI development and adoption in India. The policy emphasizes the need for AI to be developed and used in a responsible and ethical manner.
# * **Data Protection Bill**: Launched in 2019, the Data Protection Bill aims to regulate data protection in India. The bill emphasizes the need for data protection and privacy in AI development and adoption.
#
# **III. Technological Advancements and Infrastructure**
#
# India has made significant progress in AI-related technological advancements, including:
#
# 1. **Machine learning and deep learning**: Indian companies like Haptik and Zoho have developed AI-related machine learning and deep learning capabilities.
# 2. **Natural language processing**: Indian companies like Google and Microsoft have developed AI-related natural language processing capabilities.
# 3. **Computer vision**: Indian companies like Haptik and Zoho have developed AI-related computer vision capabilities.
# 4. **Robotics**: Indian companies like Haptik and Zoho have developed AI-related robotics capabilities.
#
# India has also developed infrastructure to support AI development and adoption, including:
#
# 1. **Data centers and cloud computing**: Indian companies like Amazon and Google have developed data centers and cloud computing capabilities in India.
# 2. **High-performance computing**: Indian companies like Tata Consultancy Services (TCS) and Infosys have developed high-performance computing capabilities.
# 3. **AI-specific hardware and software**: Indian companies like Haptik and Zoho have developed AI-specific hardware and software.
#
# **IV. Entrepreneurial Spirit and Start-ups**
#
# India has a thriving entrepreneurial spirit, with many AI-related start-ups emerging in recent years. Some notable AI-related start-ups in India include:
#
# 1. **Haptik**: Haptik is an AI-powered chatbot platform that provides customer service and support to businesses.
# 2. **Zoho**: Zoho is an AI-powered software company that provides a range of products, including CRM, marketing automation, and project management.
# 3. **InMobi**: InMobi is an AI-powered advertising platform that provides mobile advertising solutions to businesses.
#
# Indian start-ups face challenges in the AI space, including:
#
# 1. **Access to funding**: Indian start-ups often face challenges in accessing funding for AI-related projects.
# 2. **Talent acquisition**: Indian start-ups often face challenges in acquiring talent with AI-related skills.
# 3. **Regulatory frameworks**: Indian start-ups often face challenges in navigating regulatory frameworks related to AI.
#
# **V. Applications and Use Cases**
#
# AI has a wide range of applications in various sectors, including:
#
# 1. **Healthcare**: AI is being used in healthcare to develop predictive analytics, diagnosis, and treatment plans.
# 2. **Finance**: AI is being used in finance to develop predictive analytics, risk management, and customer service.
# 3. **Education**: AI is being used in education to develop personalized learning, adaptive assessments, and intelligent tutoring systems.
# 4. **Transportation**: AI is being used in transportation to develop autonomous vehicles, traffic management, and logistics optimization.
# 5. **Agriculture**: AI is being used in agriculture to develop precision farming, crop monitoring, and yield prediction.
#
# **VI. Challenges and Concerns**
#
# AI raises several challenges and concerns in India, including:
#
# 1. **Data privacy and security**: AI requires large amounts of data, which raises concerns about data privacy and security.
# 2. **Job displacement and skills gap**: AI has the potential to displace jobs and create a skills gap in India.
# 3. **Bias and ethics in AI**: AI can perpetuate biases and ethics, which raises concerns about fairness and accountability.
# 4. **Regulatory frameworks and governance**: AI requires regulatory frameworks and governance to ensure responsible development and adoption.
#
# **VII. Future Prospects and Opportunities**
#
# The future of AI in India is promising, with several emerging trends and technologies, including:
#
# 1. **Edge AI**: Edge AI refers to the use of AI at the edge of the network, closer to the user.
# 2. **Explainable AI**: Explainable AI refers to the use of AI that provides transparency and interpretability.
# 3. **Transfer learning**: Transfer learning refers to the use of AI that allows models to learn from one task and apply to another.
# 4. **Human-AI collaboration**: Human-AI collaboration refers to the use of AI that collaborates with humans to achieve a common goal.
#
# AI has the potential to transform India's development goals, including:
#
# 1. **Inclusive growth**: AI can help achieve inclusive growth by providing opportunities for marginalized communities.
# 2. **Job creation**: AI can help create jobs in emerging sectors, including AI development and deployment.
# 3. **Improved healthcare**: AI can help improve healthcare outcomes by providing predictive analytics and personalized medicine.
# 4. **Environmental sustainability**: AI can help achieve environmental sustainability by providing insights on energy consumption and waste management.
#
# **VIII. Conclusion**
#
# The rise of AI in India is a transformative force that has the potential to drive innovation and growth. With its growing economy, entrepreneurial spirit, and government initiatives, India is well-positioned to harness the power of AI and drive innovation. However, AI also raises several challenges and concerns, including data privacy and security, job displacement and skills gap, bias and ethics in AI, and regulatory frameworks and governance. As India continues to develop and adopt AI, it is essential to address these challenges and concerns to ensure responsible development and adoption.
#
# **IX. References**
#
# 1. **National Policy on AI** (2018)
# 2. **Data Protection Bill** (2019)
# 3. **Digital India** (2015)
# 4. **Make in India** (2014)
# 5. **Start-up India** (2016)
# 6. **AI for All** (2018)
# 7. **Haptik** (2013)
# 8. **Zoho** (1996)
# 9. **InMobi** (2007)
# 10. **Tata Consultancy Services (TCS)** (1968)
# 11. **Infosys** (1981)
# 12. **Amazon** (1994)
# 13. **Google** (1998)
# 14. **Microsoft** (1975)
#
# Note: The references provided are a selection of sources used in the blog post and are not an exhaustive list.
